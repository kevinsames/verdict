# %% [markdown]
# # Send Alert
#
# Sends alerts based on regression verdict

# %%
import sys, os, json
from datetime import datetime
import requests

notebook_dir = os.getcwd()
src_path = os.path.join(os.path.dirname(notebook_dir), 'src')
if src_path not in sys.path: sys.path.insert(0, src_path)

import logging
logging.basicConfig(level=logging.INFO)

from verdict.orchestration import RunContext

# %%
# Get run context
dbutils.widgets.text("run_id", "", "Run ID")
dbutils.widgets.text("catalog_name", "verdict_dev", "Catalog Name")

run_id = dbutils.widgets.get("run_id") or None
catalog_name = dbutils.widgets.get("catalog_name")

if run_id:
    ctx = RunContext.from_run_id(spark, catalog_name, run_id)
    config = ctx.get_config()
    verdict = ctx.get_output("verdict")
    report = ctx.get_output("verdict_report")
    candidate_version = ctx.get_output("candidate_version")
    baseline_version = ctx.get_output("baseline_version")
    alerts_config = config.get("alerts", {})
    webhook_secret = alerts_config.get("webhook_secret", "verdict/alerts_webhook")
    on_labels = alerts_config.get("on_labels", ["WARN", "FAIL"])
else:
    dbutils.widgets.text("verdict", "", "Verdict")
    dbutils.widgets.text("verdict_report", "", "Verdict Report JSON")
    dbutils.widgets.text("webhook_secret", "verdict/alerts_webhook", "Webhook Secret")
    ctx, config = None, {}, None
    verdict = dbutils.widgets.get("verdict")
    try:
        report = json.loads(dbutils.widgets.get("verdict_report"))
    except:
        report = {}
    webhook_secret = dbutils.widgets.get("webhook_secret")
    on_labels = ["WARN", "FAIL"]

logging.getLogger(__name__).info(f"Verdict: {verdict}")

# %%
if ctx:
    ctx.update_task_status("alert", "running")

# %%
should_alert = verdict in on_labels

# %%
def send_webhook(url: str, data: dict) -> bool:
    try:
        resp = requests.post(url, json=data, headers={"Content-Type": "application/json"}, timeout=30)
        return resp.status_code == 200
    except Exception as e:
        logging.getLogger(__name__).error(f"Webhook failed: {e}")
        return False

# %%
if should_alert:
    webhook_url = None
    try:
        if "/" in webhook_secret:
            scope, key = webhook_secret.split("/")
            webhook_url = dbutils.secrets.get(scope, key)
    except Exception as e:
        logging.getLogger(__name__).warning(f"Could not get webhook: {e}")

    if webhook_url:
        payload = {
            "verdict": report.get("verdict"),
            "candidate_version": report.get("candidate_version"),
            "baseline_version": report.get("baseline_version"),
            "timestamp": datetime.now().isoformat(),
            "regressions": [c for c in report.get("comparisons", []) if c.get("is_regression")]
        }
        if send_webhook(webhook_url, payload):
            logging.getLogger(__name__).info("Webhook sent")
        else:
            logging.getLogger(__name__).error("Webhook failed")

    print(f"\n{'='*60}\nALERT SENT\n{'='*60}")
    print(f"Verdict: {verdict}")
    print(f"Candidate: {report.get('candidate_version')}")
    print(f"Baseline: {report.get('baseline_version')}")
    regressions = [c for c in report.get("comparisons", []) if c.get("is_regression")]
    if regressions:
        print("\nRegressions:")
        for r in regressions:
            print(f"  - {r.get('metric_name')}: {r.get('pct_change', 0):+.2f}%")
    print(f"{'='*60}\n")
else:
    print(f"\n\u2713 No alert needed. Verdict: {verdict}\n")

# %%
# Complete
if ctx:
    ctx.set_output("alert_sent", should_alert)
    ctx.set_output("final_verdict", verdict)
    ctx.update_task_status("alert", "completed")
    ctx.complete_run(ctx.STATUS_COMPLETED if verdict == "PASS" else ctx.STATUS_RUNNING)

# %%
dbutils.jobs.taskValues.set("alert_sent", should_alert)
dbutils.jobs.taskValues.set("final_verdict", verdict)
